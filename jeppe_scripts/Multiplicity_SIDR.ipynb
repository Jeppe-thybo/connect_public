# %%
import numpy as np
import matplotlib.pyplot as plt
chain_data_0 = np.loadtxt('/home/jeppethybo/connect_public/Grendel_files/SIDR_interacting_and_std/2026-02-27_200000__0.txt')

for chain_num in range(0,6):
    chain_data = np.loadtxt(f'/home/jeppethybo/connect_public/Grendel_files/SIDR_interacting_and_std/2026-02-27_200000__{chain_num}.txt')

    plt.plot(range(chain_data.shape[0]), chain_data[:, 0], label=f'Chain {chain_num}')

# %%
import numpy as np
import matplotlib.pyplot as plt
chain_data_0 = np.loadtxt('/home/jeppethybo/connect_public/Grendel_files/SIDR_interacting_and_std_T_3_1mio/2026-03-25_1000000__1.txt')

for chain_num in range(1,7):
    chain_data = np.loadtxt(f'/home/jeppethybo/connect_public/Grendel_files/SIDR_interacting_and_std_T_3_1mio/2026-03-25_1000000__{chain_num}.txt')

    plt.plot(range(chain_data.shape[0]), chain_data[:, 0], label=f'Chain {chain_num}')
